# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1=pd.read_csv('Unemployment in India.csv')
data2=pd.read_csv('Unemployment_Rate_upto_11_2020.csv')
data1_cleaned = data1.dropna()
data1_cleaned
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 749     West Bengal   29-02-2020    Monthly                              7.55
# 750     West Bengal   31-03-2020    Monthly                              6.67
# 751     West Bengal   30-04-2020    Monthly                             15.63
# 752     West Bengal   31-05-2020    Monthly                             15.22
# 753     West Bengal   30-06-2020    Monthly                              9.86
#
# ...

# %%
data2.columns=["Region","Date","Frequency","EstimatedUnemploymentRate","EstEmployed","EstLabourParticipationRate","Area","Longitude","Latitude"]
data2
# Out:
#              Region         Date Frequency  EstimatedUnemploymentRate  \
# 0    Andhra Pradesh   31-01-2020         M                       5.48
# 1    Andhra Pradesh   29-02-2020         M                       5.83
# 2    Andhra Pradesh   31-03-2020         M                       5.79
# 3    Andhra Pradesh   30-04-2020         M                      20.51
# 4    Andhra Pradesh   31-05-2020         M                      17.43
# ..              ...          ...       ...                        ...
# 262     West Bengal   30-06-2020         M                       7.29
# 263     West Bengal   31-07-2020         M                       6.83
# 264     West Bengal   31-08-2020         M                      14.87
# 265     West Bengal   30-09-2020         M                       9.35
# 266     West Bengal   31-10-2020         M                       9.98
#
#      EstEmployed  EstLabourParticipationRate   Area  Longitude  Latitude
# ...

# %%
data2.head()
# Out:
#            Region         Date Frequency  EstimatedUnemploymentRate  \
# 0  Andhra Pradesh   31-01-2020         M                       5.48
# 1  Andhra Pradesh   29-02-2020         M                       5.83
# 2  Andhra Pradesh   31-03-2020         M                       5.79
# 3  Andhra Pradesh   30-04-2020         M                      20.51
# 4  Andhra Pradesh   31-05-2020         M                      17.43
#
#    EstEmployed  EstLabourParticipationRate   Area  Longitude  Latitude
# 0     16635535                       41.02  South    15.9129     79.74
# 1     16545652                       40.90  South    15.9129     79.74
# 2     15881197                       39.18  South    15.9129     79.74
# 3     11336911                       33.10  South    15.9129     79.74
# 4     12988845                       36.46  South    15.9129     79.74

# %%
data2.columns
# Out:
# Index(['Region', 'Date', 'Frequency', 'EstimatedUnemploymentRate',
#        'EstEmployed', 'EstLabourParticipationRate', 'Area', 'Longitude',
#        'Latitude'],
#       dtype='object')

# %%
plt.figure(dpi=100, figsize=(7,7))
plt.title("Unemployment in India")
sns.histplot(x="EstEmployed", hue="Region", data=data2, palette='Set2')
plt.show()

# %%
plt.figure(dpi=100, figsize=(7,7))
plt.title("Unemployment in India")
sns.histplot(x="EstEmployed", hue="Area", data=data2, palette='Set1')
plt.show()

# %%
pd.crosstab(data1_cleaned.Area,data1_cleaned.Region).plot(kind='bar')
# Out:
# <Axes: xlabel='Area'>
